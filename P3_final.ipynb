# %% [markdown]
# # 1. Introduction

# %% [markdown]
# [1. Introduction](#1.-introduction)
# &emsp;&emsp;&emsp;&emsp;[1.1. Virtual environment setup](#1.1.-virtual-environment-setup)
# &emsp;&emsp;&emsp;&emsp;[1.2. Libraries import](#1.2.-libraries-import)
# &emsp;&emsp;&emsp;&emsp;[1.3. Paths definition](#1.3.-paths-definition)
# &emsp;&emsp;&emsp;&emsp;[1.4. Functions definition](#1.4.-functions-definition)
# [2. Data handling](#2.-data-handling)
# &emsp;&emsp;&emsp;&emsp;[2.1. Data import](#2.1.-data-import)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.1.1. Import text files](#2.1.1.-import-text-files)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.1.2. Load the other data](#2.1.2.-load-the-other-data)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.1.3. Data types](#2.1.3.-data-types)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.1.3.1. Quick preprocessing to](#2.1.3.1.-quick-preprocessing-to)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.1.3.2. Check the types](#2.1.3.2.-check-the-types)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.1.3.3. Change the types](#2.1.3.3.-change-the-types)
# &emsp;&emsp;&emsp;&emsp;[2.2. Data combination](#2.2.-data-combination)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.2.1. Preprocessing](#2.2.1.-preprocessing)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.2.1.1. 2.2.1.1 Add locations](#2.2.1.1.-2.2.1.1-add-locations)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.2.1.2. Standardize ratings_BA and ratings_RB annually](#2.2.1.2.-standardize-ratings_ba-and-ratings_rb-annually)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.2.1.3. Preprocess and Standardization of the matched' ratings](#2.2.1.3.-preprocess-and-standardization-of-the-matched'-ratings)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.2.2. Summaries standardized data](#2.2.2.-summaries-standardized-data)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.2.3. Concatenation of the dataframes](#2.2.3.-concatenation-of-the-dataframes)
# &emsp;&emsp;&emsp;&emsp;[2.3. Data exploration](#2.3.-data-exploration)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.3.1. All over the world](#2.3.1.-all-over-the-world)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.3.1.1. 2.3.1.1 Breweries and reviews in the world](#2.3.1.1.-2.3.1.1-breweries-and-reviews-in-the-world)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.3.2. Reviews' pre-processing](#2.3.2.-reviews'-pre-processing)
# [3. Data Analysis](#3.-data-analysis)
# &emsp;&emsp;&emsp;&emsp;[3.1. Numerical ranking](#3.1.-numerical-ranking)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.1.1. Filtering of the data](#3.1.1.-filtering-of-the-data)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.1.2. Weighted ranking](#3.1.2.-weighted-ranking)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.1.2.1. All-time weighted ranking](#3.1.2.1.-all-time-weighted-ranking)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.1.2.2. Weighted ranking per year](#3.1.2.2.-weighted-ranking-per-year)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.1.3. Quality-based ranking](#3.1.3.-quality-based-ranking)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.1.3.1. All time quality ranking](#3.1.3.1.-all-time-quality-ranking)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.1.3.2. Quality ranking per year](#3.1.3.2.-quality-ranking-per-year)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.1.4. Comparison of the two all-time rankings](#3.1.4.-comparison-of-the-two-all-time-rankings)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.1.5. Evolution of the best breweries grade across the years](#3.1.5.-evolution-of-the-best-breweries-grade-across-the-years)
# &emsp;&emsp;&emsp;&emsp;[3.2. Link between polarity, subjectivity of the reviews and ratings](#3.2.-link-between-polarity,-subjectivity-of-the-reviews-and-ratings)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.2.1. Reviews' preprocessing](#3.2.1.-reviews'-preprocessing)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.2.2. Calculations of polarity and subjectivity of the reviews with NLP analysis](#3.2.2.-calculations-of-polarity-and-subjectivity-of-the-reviews-with-nlp-analysis)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.2.3. Statistics](#3.2.3.-statistics)
# &emsp;&emsp;&emsp;&emsp;[3.3. NLP-Augmented ranking](#3.3.-nlp-augmented-ranking)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.3.0.1. New ranking system](#3.3.0.1.-new-ranking-system)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.3.1. New weighted ranking](#3.3.1.-new-weighted-ranking)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.3.1.1. 3.3.2.1 All-time new weighted ranking](#3.3.1.1.-3.3.2.1-all-time-new-weighted-ranking)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.3.1.2. New weighted ranking per year](#3.3.1.2.-new-weighted-ranking-per-year)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.3.2. New quality-based ranking](#3.3.2.-new-quality-based-ranking)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.3.2.1. All-time new quality-based ranking](#3.3.2.1.-all-time-new-quality-based-ranking)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.3.2.2. New quality-based ranking per year](#3.3.2.2.-new-quality-based-ranking-per-year)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[3.3.3. Comparison of the two all-time augmented rankings ](#3.3.3.-comparison-of-the-two-all-time-augmented-rankings-)
# [4. Annexes](#4.-annexes)
# &emsp;&emsp;&emsp;&emsp;[4.1. GeoJson creation of the interactive world maps](#4.1.-geojson-creation-of-the-interactive-world-maps)
# &emsp;&emsp;&emsp;&emsp;[4.2. Generation of the table of content](#4.2.-generation-of-the-table-of-content)

# %% [markdown]
# ## 1.1. Virtual environment setup

# %% [markdown]
# In order to run this notebook, you need to create a virtual environment with the command lines that are provided in the [README.md](https://github.com/epfl-ada/ada-2023-project-laremontada61/blob/main/README.md) file at the root of the repository.

# %% [markdown]
# ## 1.2. Libraries import

# %%
# import all the libraries
import os
import warnings
import nbformat

import numpy as np
import pandas as pd
import regex as re
import country_converter as coco
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
import plotly.graph_objects as pg
import plotly.express as px
import plotly.graph_objects as go
import spacy
import kaleido
import json

from IPython.display import display, HTML, Markdown, Image
from textblob import TextBlob

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import string
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

from wordcloud import WordCloud
from collections import Counter
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import plotly.graph_objects as go
from random import sample

# statistics
from scipy.stats import ttest_rel, ttest_ind, mannwhitneyu, pearsonr
import statsmodels.formula.api as smf
import scipy.optimize as optimize

warnings.filterwarnings('ignore') # remove the warnings

# %% [markdown]
# ## 1.3. Paths definition

# %%
#mettre les paths 
output_plot_folder = "docs/assets/plot/"
output_img_folder = "docs/assets/img/"

# %% [markdown]
# ## 1.4. Functions definition

# %%
# A function is defined to save the plots in .html and .png format
def plot_format (fig, name):
    fig.write_html(output_plot_folder + name + ".html")
    fig.write_image(output_img_folder + name + ".png", engine="kaleido")

    #Show plot image in notebook
    return Image(output_img_folder + name + ".png")

# %%
from datetime import datetime
tic = datetime.now()

# %% [markdown]
# # 2. Data handling

# %% [markdown]
# ## 2.1. Data import

# %% [markdown]
# As we've seen in Milestone P2, loading directly the "rating.txt" with a standard pipeline is impractical due to laptop memory limitations. We thus splitted the .txt files into N subfiles and load the data iteratively using a function.
#
# The function allows control over the fraction of initial data loaded via the parameter *Nb_files*, which determines the number of subfiles to load. It also accommodates inherent differences between the two websites, such as additional review columns for BeerAdvocate.
#
# We'd like to load the maximal fraction of intial data thus the maximum number of files.
#
# Thanks to this loading strategy, we managed to load all the data from the two ratings websites in a dataframe instance without having to sample element from them.

# %% [markdown]
# ### 2.1.1. Import text files

# %%
def load_txt_file(website, Nb_files):
    if website == 'BeerAdvocate':
        # Specify the directory containing the text files 
        # Need to be outside of the repo folder and might need to change the path according to one's unique folders configuration
        directory = './../dataset_BeerReviews/BeerAdvocate/'
    else:
        directory = './../dataset_BeerReviews/RateBeer/'
        
    # Initialize an empty list to store DataFrames
    dfs = []

    # Loop through the files in reverse order (ratings-5.txt to ratings-1.txt)
    for i in range(Nb_files, 0, -1):
        file_name = f'ratings-{i}.txt'
        file_path = os.path.join(directory, file_name)

        with open(file_path, 'r') as f:
            text = f.read()

        # Remove double quotes at the beginning of each line
        data = re.sub('"', '', text)
        data = re.sub(r'^"', '', data, flags=re.MULTILINE)

        # Split the text into individual beer reviews
        beer_reviews = data.split('beer_name')

        # Extract the beer information from each review
        beer_data = []
        for review in beer_reviews:
            beer_info = {}
            for line in [entry.split(':', 1) for entry in review.split('\n') if ':' in entry]:# and 'text' not in entry]:
                if line:  # Check if the list is not empty
                    key, value = line[0].strip(), line[1].strip()
                    beer_info[key] = value
            beer_data.append(beer_info)

        # Convert the beer data into a DataFrame
        df = pd.DataFrame(beer_data)

        # Append the DataFrame to the list
        dfs.append(df)

    # Concatenate all DataFrames into a single DataFrame
    final_df = pd.concat(dfs, ignore_index=True)

    # Rename the columns depending on the website
    if website == 'BeerAdvocate':
        final_df.columns = [
            'beer_name',
            'beer_id',
            'brewery_name',
            'brewery_id',
            'style',
            'abv',
            'date',
            'user_name',
            'user_id',
            'appearance',
            'aroma',
            'palate',
            'taste',
            'overall',
            'rating',
            'text',
            'review'] # additional column compared to RB
    else:
        final_df.columns = [
            'beer_name',
            'beer_id',
            'brewery_name',
            'brewery_id',
            'style',
            'abv',
            'date',
            'user_name',
            'user_id',
            'appearance',
            'aroma',
            'palate',
            'taste',
            'overall',
            'rating',
            'text']
    return final_df

def sample_data(df, ratio):
    # sample the data to make it even smaller
    return df.sample(frac = ratio, random_state=42)

# %%
# Load data : We load the whole data from both website, there are 19 Beer Advocate files and 16 Rate Beer files
ratings_BA = load_txt_file('BeerAdvocate', 19)
ratings_RB = load_txt_file('RateBeer', 16)

# %%
print(f"Length of ratings_BA (BeerAdvocate) dataframe : {len(ratings_BA)}")
print(f"Length of ratings_RB (RateBeer) dataframe : {len(ratings_RB)}")
display(ratings_BA.head(2),ratings_RB.head(2))
# Out:
# Length of ratings_BA (BeerAdvocate) dataframe : 8302445
# Length of ratings_RB (RateBeer) dataframe : 7122076
#                beer_name beer_id                  brewery_name brewery_id  \
# 225264     Posca Rustica   73367         Brasserie Dupont sprl        637
# 7981675  Adnams Explorer   20121  Adnams plc, Sole Bay Brewery        779
#
#                                        style  abv        date user_name  \
# 225264   Scottish Gruit / Ancient Herbed Ale  8.0  1345716000  jsanford
# 7981675                  American Blonde Ale  5.0  1426158000    Sellen
#
#                  user_id appearance aroma palate taste overall rating  \
# 225264   jsanford.430116        4.0   3.5    3.5   3.0     3.5   3.33
# 7981675    sellen.828879       3.25  3.25    3.0  3.25    3.25   3.23
#
#                                                       text review
# 225264   Pours a light, clear gold with a thin white ri...   True
# 7981675                                                nan  False
# ...

# %% [markdown]
# ### 2.1.2. Load the other data

# %%
# BeerAdvocate
beers_BA = pd.read_csv("./../dataset_BeerReviews/BeerAdvocate/beers.csv")
breweries_BA = pd.read_csv("./../dataset_BeerReviews/BeerAdvocate/breweries.csv")
users_BA = pd.read_csv("./../dataset_BeerReviews/BeerAdvocate/users.csv")

# RateBeer
beers_RB = pd.read_csv("./../dataset_BeerReviews/RateBeer/beers.csv")
breweries_RB = pd.read_csv("./../dataset_BeerReviews/RateBeer/breweries.csv")
users_RB = pd.read_csv("./../dataset_BeerReviews/RateBeer/users.csv")

# matched_beer_data
beers_matched = pd.read_csv("./../dataset_BeerReviews/matched_beer_data/beers.csv", header=1)
breweries_matched = pd.read_csv("./../dataset_BeerReviews/matched_beer_data/breweries.csv", header = 1)
ratings_matched = pd.read_csv("./../dataset_BeerReviews/matched_beer_data/ratings.csv", header=1)
users_matched = pd.read_csv("./../dataset_BeerReviews/matched_beer_data/users.csv", header=1)

# %% [markdown]
# ### 2.1.3. Data types

# %% [markdown]
# #### 2.1.3.1. Features' selection

# %% [markdown]
# Some features are not useful for our analysis, we thus remove them from the dataframes for faster processing.

# %%
ratings_BA.drop(columns=['abv', 'appearance', 'aroma', 'palate', 'taste', 'overall', 'review'], inplace=True)
ratings_RB.drop(columns=['abv', 'appearance', 'aroma', 'palate', 'taste', 'overall'], inplace=True)
ratings_matched.drop(columns=['abv', 'appearance', 'aroma', 'palate', 'taste', 'overall', 'review',
                            'abv.1', 'appearance.1', 'aroma.1', 'palate.1', 'taste.1', 'overall.1'], inplace=True)

# %% [markdown]
# #### 2.1.3.2. Check the types

# %%
# Get types of the features in each DataFrame
df_types = pd.concat([df.dtypes.rename(f"DataFrame {i+1}") for i, df in enumerate([ratings_BA, ratings_RB])], axis=1)
df_types
# Out:
#              DataFrame 1 DataFrame 2
# beer_name         object      object
# beer_id           object      object
# brewery_name      object      object
# brewery_id        object      object
# style             object      object
# date              object      object
# user_name         object      object
# user_id           object      object
# rating            object      object
# text              object      object

# %% [markdown]
# #### 2.1.3.3. Change the types

# %% [markdown]
# One can see that all the features of **ratings_BA** and **ratings_RB** have a `object` type, which is not very convenient if we want to automate the visualization process, for example plotting the distribution of the numerical features in histograms. As a first preprocessing step, we will thus convert the type of the numerical values with the function **convert_type** below. The different id columns are converted to `int64` type and the ratings columns to `float64` type.
# We also drop the rows with missing values in the columns `brewery_id` and `beer_id` as they are not useful for our analysis.

# %%
def convert_type(df, col, type):
    if type == 'int':
        # Replace NaN with -1
        df[col].fillna(-1, inplace=True)

        # Convert the column to int64
        df[col] = df[col].astype('int64')

        #Drop rows where the column has the value -1
        df = df[df[col] != -1]
    elif type == 'float':
        df[col] = df[col].astype('float64')
    return df

# columns including the numerical features for both websites
# user_id is numerical in RB but categorical in BA so we don't include it
float_col = ['rating']
int_col = ['beer_id', 'brewery_id']

# Skipping na for better processing
ratings_BA = ratings_BA[~(ratings_BA["beer_id"].isna())]
ratings_BA = ratings_BA[~(ratings_BA["brewery_name"].isna())]
ratings_RB = ratings_RB[~(ratings_RB["beer_id"].isna())]
ratings_RB = ratings_RB[~(ratings_RB["brewery_name"].isna())]

# %%
for col in float_col : 
    ratings_BA= convert_type(ratings_BA, col, 'float')
    ratings_RB = convert_type(ratings_RB, col, 'float')
for col in int_col : 
    ratings_BA = convert_type(ratings_BA, col, 'int')
    ratings_RB = convert_type(ratings_RB, col, 'int')
ratings_RB.rating = ratings_RB.rating.astype('float64').dropna()

# %%
# check types of features in each DataFrame to make sure they are correct
df_types = pd.concat([df.dtypes.rename(f"DataFrame {i+1}") for i, df in enumerate([ratings_BA, ratings_RB])], axis=1)
df_types
# Out:
#              DataFrame 1 DataFrame 2
# beer_name         object      object
# beer_id            int64       int64
# brewery_name      object      object
# brewery_id         int64       int64
# style             object      object
# date              object      object
# user_name         object      object
# user_id           object      object
# rating           float64     float64
# text              object      object

# %% [markdown]
# ## 2.2. Data combination

# %% [markdown]
# We would like to have a single dataframe containing all the data from the two websites. We will thus combine the data from **ratings_BA** and **ratings_RB** with the data from **matched**. We will also add the location of the breweries from **breweries** to the combined dataframe.
# However, before combining the data, we need to standardize them to make them comparable, and remove any dependency of the websites.
# We need to standardize the data from **ratings_BA** and **ratings_RB** before combining them with **matched**, which has already been standardized per year and per website.
#
# The **matched** rows' structure is composed of **ratings_BA** and **ratings_RB** data that we need to split in 2 rows. The first row will contain the data from **ratings_BA** and the second row the data from **ratings_RB**, for every matched row.

# %% [markdown]
# ### 2.2.1. Preprocessing

# %% [markdown]
# #### 2.2.1.1 Add locations

# %%
def add_location(breweries_df, users_df, ratings_df, nb):
    # Rename the columns and convert 'brewery_id' and 'user_id' to str
    breweries_df = breweries_df.rename(columns={'id': 'brewery_id', 'location': 'brewery_location'})
    breweries_df['brewery_id'] = breweries_df['brewery_id'].astype(str)
    users_df = users_df.rename(columns={'location': 'user_location'})
    users_df['user_id'] = users_df['user_id'].astype(str)
    ratings_df['brewery_id'] = ratings_df['brewery_id'].astype(str)
    ratings_df['user_id'] = ratings_df['user_id'].astype(str)

    # Merge the DataFrames
    ratings_df_merged = pd.merge(ratings_df, breweries_df[['brewery_id', 'brewery_location']], on='brewery_id', how='left')
    ratings_df_merged = pd.merge(ratings_df_merged, users_df[['user_id', 'user_location']], on='user_id', how='left')

    # Change the order of the columns
    if nb == 1:
        column_b = ratings_df_merged.pop('brewery_location')
        ratings_df_merged.insert(4, 'brewery_location', column_b)
        column_u = ratings_df_merged.pop('user_location')
        ratings_df_merged.insert(9, 'user_location', column_u)
    else:
        column_b = ratings_df_merged.pop('brewery_location')
        ratings_df_merged.insert(4, 'brewery_location', column_b)
        ratings_df_merged.insert(15, 'brewery_location.1', column_b)
        column_u = ratings_df_merged.pop('user_location')
        ratings_df_merged.insert(11, 'user_location', column_u)
        ratings_df_merged.insert(23, 'user_location.1', column_u)
    

    return ratings_df_merged

# %%
# Modify the data before concatenating (to add locations of users and breweries)
ratings_BA = add_location(breweries_BA, users_BA, ratings_BA, 1)
ratings_RB = add_location(breweries_RB, users_RB, ratings_RB, 1)
ratings_matched = add_location(breweries_matched, users_matched, ratings_matched, 2)

display(ratings_matched.head(2), ratings_BA.head(2), ratings_RB.head(2))
# Out:
#    beer_id                beer_name brewery_id  \
# 0      645  Trappistes Rochefort 10        207
# 1    28191       Myanmar Lager Beer       9369
#
#                      brewery_name brewery_location        date  rating  \
# 0          Brasserie de Rochefort          Belgium  1324810800     4.8
# 1  Myanmar Brewery and Distillery          Myanmar  1322650800     3.0
#
#                     style                                               text  \
# 0        Quadrupel (Quad)  Best before 27.07.2016Directly reviewed in com...
# 1  American Adjunct Lager                                                NaN
#
#               user_id  ... brewery_id.1                  brewery_name.1  \
# 0     erzengel.248045  ...          406             Brasserie Rochefort
# 1  visionthing.639993  ...         2921  Myanmar Brewery and Distillery
#
#    brewery_location.1      date.1  rating.1        style.1  \
# 0             Belgium  1387710000       4.6  Abt/Quadrupel
# ...

# %% [markdown]
# #### 2.2.1.2. Standardize ratings_BA and ratings_RB annually

# %% [markdown]
# - Need to add time dimension first: month and year

# %%
def add_time_features(df):
    """
    Adds a 'month' and a 'year' features to the DataFrame based on the 'date' column.
    
    Parameters
    ----------
    df : DataFrame
        Contains data including a 'date' column.

    Returns
    -------
    df_m : DataFrame
        Contains the original data with an additional 'month' and 'year' features.
    """
    # Create a copy of the DataFrame
    df_time = df.copy()
    # Conversion of date feature from timestamp to text date
    pd.to_numeric(df_time['date'], errors='coerce', downcast='integer')
    # Convert 'date' to datetime and extract the date
    df_time.date = df.date.apply(lambda d: pd.to_datetime(d, unit='s'))
    df_time['date'] = df_time['date'].dt.date

    # Extract the month from the 'date' column and add it as a new feature 'month'
    df_time['month'] = pd.to_datetime(df_time['date']).dt.month
    # Extract the year from the 'date' column and add it as a new feature 'year'
    df_time['year'] = pd.to_datetime(df_time['date']).dt.year

    return df_time

def standardize_annually(df, col_to_standardize):
    """
    Standardizes the ratings annually and per website.
    
    Parameters
    ----------
    df : DataFrame
        Containing all data
    col_to_standardize : string, used for several columns in the notebook

    Returns
    -------
    df : DataFrame
        Containing all data with standardized ratings with additional column 'standardized_rating'.
                
    """
    df_copy = df.copy()
    grouped = df_copy.groupby('year')[col_to_standardize].agg(['mean', 'std'])
    df_copy = pd.merge(df_copy, grouped, left_on='year', right_index=True)
    df_copy[f"std_{col_to_standardize}"] = (df_copy[col_to_standardize] - df_copy['mean']) / df_copy['std']
    df_copy.drop(columns = ['mean', 'std'], inplace=True)
    
    return df_copy, grouped

# %%
# add time feature to standardize ratings by year and by website
ratings_BA_with_time = add_time_features(ratings_BA)
ratings_RB_with_time = add_time_features(ratings_RB)

# apply standardization
ratings_BA_standardized, mean_std_BA = standardize_annually(ratings_BA_with_time, 'rating')
ratings_RB_standardized, mean_std_RB = standardize_annually(ratings_RB_with_time, 'rating')

display(ratings_BA_standardized.head(2), ratings_RB_standardized.head(2))
# Out:
#                       beer_name  beer_id                  brewery_name  \
# 0                 Posca Rustica    73367         Brasserie Dupont sprl
# 25  Coney Island Freaktoberfest    43442  Coney Island Brewing Company
#
#    brewery_id         brewery_location                                style  \
# 0         637                  Belgium  Scottish Gruit / Ancient Herbed Ale
# 25      27114  United States, New York                          Pumpkin Ale
#
#           date      user_name               user_id             user_location  \
# 0   2012-08-23       jsanford       jsanford.430116    United States, Georgia
# 25  2012-05-23  millelacsmark  millelacsmark.279958  United States, Minnesota
#
#     rating                                               text  month  year  \
# 0     3.33  Pours a light, clear gold with a thin white ri...      8  2012
# 25    3.00                                                nan      5  2012
#
#     std_rating
# 0    -0.656708
# 25   -1.117057
# ...

# %%
min_year_BA = ratings_BA_standardized['year'].min()
max_year_BA = ratings_BA_standardized['year'].max()
min_year_RB = ratings_RB_standardized['year'].min()
max_year_RB = ratings_RB_standardized['year'].max()

print(f"BeerAdvocate - Min year: {min_year_BA}, Max year: {max_year_BA}")
print(f"RateBeer - Min year: {min_year_RB}, Max year: {max_year_RB}")

fig, axs = plt.subplots(1, 2, figsize=(15, 5))
sns.histplot(data=ratings_BA_standardized, bins = 15, x="year", ax = axs[0])
sns.histplot(data=ratings_RB_standardized, bins = 15, x="year", ax = axs[1])

axs[0].set_xticks(np.arange(ratings_BA_standardized['year'].min(), ratings_BA_standardized['year'].max() + 1, 2))
axs[1].set_xticks(np.arange(ratings_RB_standardized['year'].min(), ratings_RB_standardized['year'].max() + 1, 2))

axs[0].set_title("Yearly distribution of reviews on BeerAdvocate")
axs[1].set_title("Yearly distribution of reviews on RateBeer")
plt.tight_layout()
plt.show()
# Out:
# BeerAdvocate - Min year: 1996, Max year: 2017
# RateBeer - Min year: 2000, Max year: 2017

# %%
def plot_mean_std_errorbar(grouped_BA, grouped_RB):
    plt.figure(figsize=(7, 7))
    plt.subplot(2, 1, 1)
    plt.errorbar(grouped_BA.index, grouped_BA['mean'], yerr=1.96 * grouped_BA['std'] / np.sqrt(grouped_BA['std'].count()), fmt='o', capsize=5, linestyle='-', label = 'BeerAdvocate')
    plt.errorbar(grouped_RB.index, grouped_RB['mean'], yerr=1.96 * grouped_RB['std'] / np.sqrt(grouped_RB['std'].count()), fmt='o', capsize=5, linestyle='-', label = 'RateBeer')
    plt.xticks(np.arange(grouped_BA.index.min(), grouped_BA.index.max() + 1, 2))
    plt.title('Mean Ratings across Years')
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.errorbar(grouped_BA.index, grouped_BA['std'], fmt='o', linestyle='-', label = 'BeerAdvocate')
    plt.errorbar(grouped_RB.index, grouped_RB['std'], fmt='o', linestyle='-', label = 'RateBeer')
    plt.title('Standard Deviation of Ratings across Years')
    
    plt.xticks(np.arange(grouped_BA.index.min(), grouped_BA.index.max() + 1, 2))
    plt.xlabel('Years')  
    plt.tight_layout()
    plt.legend()
    plt.show()

# %% [markdown]
# Some plots

# %%
print("Before standardization")
plot_mean_std_errorbar(mean_std_BA, mean_std_RB)

# check standardization
print("Standardization check:\n")
print(f"Mean of standardized ratings for BeerAdvocate : {ratings_BA_standardized['std_rating'].mean()}")
print(f"Mean of standardized ratings for RateBeer : {ratings_RB_standardized['std_rating'].mean()}")
print(f"Standard deviation of standardized ratings for BeerAdvocate : {ratings_BA_standardized['std_rating'].std()}")
print(f"Standard deviation of standardized ratings for RateBeer : {ratings_RB_standardized['std_rating'].std()}")
# Out:
# Before standardization
# Standardization check:
#
# Mean of standardized ratings for BeerAdvocate : 1.6171510183502675e-16
# Mean of standardized ratings for RateBeer : 1.3921921409061613e-16
# Standard deviation of standardized ratings for BeerAdvocate : 0.9999988557550757
# Standard deviation of standardized ratings for RateBeer : 0.9999988068140335

# %% [markdown]
# Looking at the graphs above, we decide to remove the data from BeerAdvocate to be consistent with the time window of RateBeer that only has reviews from the year 2000 onwards.

# %%
print(f"Number of reviews in BeerAdvocate before 2000: {len(ratings_BA_standardized[ratings_BA_standardized.year < 2000])}")

# keep only the reviews from 2000 onwards
ratings_BA_standardized = ratings_BA_standardized[ratings_BA_standardized['year'] >= 2000]
# Out:
# Number of reviews in BeerAdvocate before 2000: 218

# %% [markdown]
# #### 2.2.1.3. Preprocess and Standardization of the matched' ratings

# %% [markdown]
# We first preprocess the **ratings_matched** dataframe, which has initially 2 reviews per row, one from BeerAdvocate and one from RateBeer (see below).

# %%
ratings_matched.head(2)
# Out:
#    beer_id                beer_name brewery_id  \
# 0      645  Trappistes Rochefort 10        207
# 1    28191       Myanmar Lager Beer       9369
#
#                      brewery_name brewery_location        date  rating  \
# 0          Brasserie de Rochefort          Belgium  1324810800     4.8
# 1  Myanmar Brewery and Distillery          Myanmar  1322650800     3.0
#
#                     style                                               text  \
# 0        Quadrupel (Quad)  Best before 27.07.2016Directly reviewed in com...
# 1  American Adjunct Lager                                                NaN
#
#               user_id  ... brewery_id.1                  brewery_name.1  \
# 0     erzengel.248045  ...          406             Brasserie Rochefort
# 1  visionthing.639993  ...         2921  Myanmar Brewery and Distillery
#
#    brewery_location.1      date.1  rating.1        style.1  \
# 0             Belgium  1387710000       4.6  Abt/Quadrupel
# ...

# %% [markdown]
# We thus process this dataframe to have 1 review per row, which will be added later to the **ratings_BA** and **ratings_RB** dataframes.

# %%
ratings_matched_copy = ratings_matched.copy()
ratings_matched_copy['beer_id.1'] = ratings_matched_copy['beer_id']
ratings_matched_copy['brewery_id.1'] = ratings_matched_copy['brewery_id']
ratings_matched_copy['beer_name.1'] = ratings_matched_copy['beer_name']
ratings_matched_copy['brewery_name.1'] = ratings_matched_copy['brewery_name']
ratings_matched_copy['brewery_location.1'] = ratings_matched_copy['brewery_location']
ratings_matched_copy['user_location.1'] = ratings_matched_copy['user_location']

# Retrieve the columns of interest for BeerAdvocate
ratings_matched_BA = ratings_matched_copy.iloc[:, :12]
#Retrieve the columns of interest for RateBeer
ratings_matched_RB = ratings_matched_copy.iloc[:, 12:]

# match the columns names
ratings_matched_BA = ratings_matched_BA.sort_index(axis=1)
ratings_matched_RB = ratings_matched_RB.sort_index(axis=1)
# Rename the columns to have the same name as the other datasets
ratings_matched_RB.columns = ratings_matched_BA.columns

# %%
display(ratings_matched_BA.head(2), ratings_matched_RB.head(2))
# Out:
#    beer_id                beer_name brewery_id brewery_location  \
# 0      645  Trappistes Rochefort 10        207          Belgium
# 1    28191       Myanmar Lager Beer       9369          Myanmar
#
#                      brewery_name        date  rating                   style  \
# 0          Brasserie de Rochefort  1324810800     4.8        Quadrupel (Quad)
# 1  Myanmar Brewery and Distillery  1322650800     3.0  American Adjunct Lager
#
#                                                 text             user_id  \
# 0  Best before 27.07.2016Directly reviewed in com...     erzengel.248045
# 1                                                NaN  visionthing.639993
#
#   user_location    user_name
# 0       Germany     Erzengel
# 1       Estonia  visionthing
#    beer_id                beer_name brewery_id brewery_location  \
# 0      645  Trappistes Rochefort 10        207          Belgium
# 1    28191       Myanmar Lager Beer       9369          Myanmar
#
# ...

# %%
# Compute mean values for each distribution
mean_rating_BA_matched = ratings_matched_BA['rating'].mean()
mean_rating_RB_matched = ratings_matched_RB['rating'].mean()
mean_rating_BA_standardized = ratings_BA_standardized['std_rating'].mean()
mean_rating_RB_standardized = ratings_RB_standardized['std_rating'].mean()

plt.figure(figsize=(10, 7))
sns.histplot(data=ratings_matched_BA['rating'], bins=50, label = 'ratings_BA_matched')
sns.histplot(data=ratings_matched_RB['rating'], bins=50, label = 'ratings_RB_matched')
sns.histplot(data=ratings_BA_standardized['std_rating'], bins=50, label = 'ratings_BA_standardized')
sns.histplot(data=ratings_RB_standardized['std_rating'], bins=50, label = 'ratings_RB_standardized')

# Plot vertical lines for mean values
plt.axvline(x=mean_rating_BA_matched, color='green', linestyle='--', label=f'Mean BA Matched: {mean_rating_BA_matched:.2f}')
plt.axvline(x=mean_rating_RB_matched, color='blue', linestyle='--', label=f'Mean RB Matched: {mean_rating_RB_matched:.2f}')
plt.axvline(x=mean_rating_BA_standardized, color='orange', linestyle='--', label=f'Mean BA Standardized: {mean_rating_BA_standardized:.2f}')
plt.axvline(x=mean_rating_RB_standardized, color='red', linestyle='--', label=f'Mean RB Standardized: {mean_rating_RB_standardized:.2f}')

plt.title("Before standardization of the matched dataset")
plt.legend()
plt.show()

# %% [markdown]
# One can see that the ratings from the **ratings_matched** dataframe are center around 3.6, whereas the previously processed ratings of BeerAdvocate and RateBeer are standardized and thus centered around 0. In order to combine all the data together, we need to standardize the same way the ratings from the **ratings_matched**. We do it as before, namely annually and per website.

# %%
# add time features to standardize by year
ratings_matched_BA_with_time = add_time_features(ratings_matched_BA)
ratings_matched_RB_with_time = add_time_features(ratings_matched_RB)

# standardize ratings of matched data to have mean 0 and std 1
ratings_matched_BA_standardized, mean_std_BA_matched = standardize_annually(ratings_matched_BA_with_time, 'rating') # adds column 'std_rating'
ratings_matched_RB_standardized, mean_std_RB_matched = standardize_annually(ratings_matched_RB_with_time, 'rating') # adds column 'std_rating'

# %% [markdown]
# ### 2.2.2. Summaries standardized data

# %% [markdown]
# All dataframes have an additional column 'std_rating' with the standardized rating.

# %%
# Compute mean values for each distribution
mean_rating_BA_matched = ratings_matched_BA_standardized['std_rating'].mean()
mean_rating_RB_matched = ratings_matched_RB_standardized['std_rating'].mean()
mean_rating_BA_standardized = ratings_BA_standardized['std_rating'].mean()
mean_rating_RB_standardized = ratings_RB_standardized['std_rating'].mean()

# Print the values
print(f"Mean of standardized ratings for BeerAdvocate matched dataset : {mean_rating_BA_matched}")
print(f"Mean of standardized ratings for RateBeer matched dataset : {mean_rating_RB_matched}")
print(f"Mean of standardized ratings for BeerAdvocate : {mean_rating_BA_standardized}")
print(f"Mean of standardized ratings for RateBeer : {mean_rating_RB_standardized}")
# Out:
# Mean of standardized ratings for BeerAdvocate matched dataset : -6.146563458132355e-18
# Mean of standardized ratings for RateBeer matched dataset : 1.5139956307399695e-16
# Mean of standardized ratings for BeerAdvocate : 1.617320594234177e-16
# Mean of standardized ratings for RateBeer : 1.3921921409061613e-16

# %% [markdown]
# ### 2.2.3. Concatenation of the dataframes

# %% [markdown]
# All the ratings are now standardized and we can combined all of them.

# %%
# concatenate matched data from both websites with beer_id and user_id because matched have been created to match these two features
ratings_matched_BA_RB = pd.concat([ratings_matched_BA_standardized, ratings_matched_RB_standardized], axis=0)
ratings_matched_BA_RB.sort_values(by=['beer_id', 'user_id'], inplace=True)

# concatenate matched data with ratings_BA and ratings_RB
all_data= pd.concat([ratings_BA_standardized, 
                    ratings_RB_standardized,
                    ratings_matched_BA_RB], axis=0)

print("Details of the combined dataset:\n")
print(f"Total length of combined dataset: {len(all_data)} reviews\nwith:")
print(f"    {len(ratings_matched_BA_RB)} reviews from ratings matched")
print(f"    {len(ratings_BA_standardized)} reviews from BeerAdvocate")
print(f"    {len(ratings_RB_standardized)} reviews from RateBeer")

# check
sns.histplot(data=all_data['std_rating'], bins=50)
plt.title("Distribution of ratings in the combined dataset")
plt.ylabel("Number of reviews")
plt.show()

all_data.head(2)
# Out:
# Details of the combined dataset:
#
# Total length of combined dataset: 15469925 reviews
# with:
#     43928 reviews from ratings matched
#     8302207 reviews from BeerAdvocate
#     7123790 reviews from RateBeer
#                       beer_name  beer_id                  brewery_name  \
# 0                 Posca Rustica    73367         Brasserie Dupont sprl
# 25  Coney Island Freaktoberfest    43442  Coney Island Brewing Company
#
#    brewery_id         brewery_location                                style  \
# 0         637                  Belgium  Scottish Gruit / Ancient Herbed Ale
# 25      27114  United States, New York                          Pumpkin Ale
#
#           date      user_name               user_id             user_location  \
# 0   2012-08-23       jsanford       jsanford.430116    United States, Georgia
# 25  2012-05-23  millelacsmark  millelacsmark.279958  United States, Minnesota
#
# ...

# %% [markdown]
# ## 2.3. Data exploration

# %% [markdown]
# ### 2.3.1. All over the world

# %%
print(f"Number of different breweries in all websites : {len(all_data['brewery_id'].unique())}")

def filter_topk_breweries(df, k):
    # Find the top k% of breweries most rated
    #brewery_count = pd.DataFrame({"count": df.groupby('brewery_name').apply(lambda x: len(x))})
    brewery_count = df['brewery_name'].value_counts()
    #threshold = brewery_count['count'].quantile(k)
    #top_breweries = brewery_count[brewery_count['count'] > threshold].index
    top_breweries = brewery_count.nlargest(k).index

    # Filter DataFrame based on the selected brewery names
    df_filtered = df[df['brewery_name'].isin(top_breweries)]
    return df_filtered

topK = 100
ratings_all_top_breweries = filter_topk_breweries(all_data, topK)

def plot_top_breweries(df, k):
    # Filter the top k breweries
    top_breweries = df['brewery_name'].value_counts().nlargest(k).sort_values(ascending=False)
    # Plot the distribution of ratings for the top breweries
    fig = px.histogram(top_breweries, x=top_breweries.values, y=top_breweries.index, color=top_breweries.index)
    fig.update_layout(barmode='stack', showlegend=False)
    fig.update_layout(width=900, height=1200)
    fig.update_layout(title_text=f'Top {k} breweries with the most ratings')
    fig.update_xaxes(title_text='Number of ratings')
    fig.update_yaxes(title_text='Breweries')
    return fig
# Out:
# Number of different breweries in all websites : 30090

# %%
# Call the function with the desired parameters
topK = 50
fig = plot_top_breweries(ratings_all_top_breweries, topK)

display(plot_format(fig, "top_most_rated_breweries"))

# %% [markdown]
# #### 2.3.1.1 Breweries and reviews in the world

# %%
def count_and_filtering_us_uk(df):
    # Copy the DataFrame once
    df = df.copy(deep=True)
    df['brewery_location'] = df['brewery_location'].fillna('Unknown')
    df['user_location'] = df['user_location'].fillna('Unknown')

    # Remove the rows with 'Unknown' location
    #df = df[(df['brewery_location'] != 'Unknown') & (df['user_location'] != 'Unknown')]

    # Create a mask for US and UK locations
    mask_us_brewery = df['brewery_location'].str.startswith('United States')
    mask_uk_brewery = df['brewery_location'].isin(['England', 'Scotland', 'Wales', 'Northern Ireland'])
    mask_us_user = df['user_location'].str.startswith('United States')
    mask_uk_user = df['user_location'].isin(['England', 'Scotland', 'Wales', 'Northern Ireland'])

    # Replace the location names in the original DataFrame
    df.loc[mask_us_brewery, 'brewery_location'] = 'United States'
    df.loc[mask_uk_brewery, 'brewery_location'] = 'United Kingdom'
    df.loc[mask_us_user, 'user_location'] = 'United States'
    df.loc[mask_uk_user, 'user_location'] = 'United Kingdom'

    # Count the number of breweries per location excluding US and UK
    number_of_brewery_per_country = df.groupby('brewery_location')['brewery_id'].nunique().rename("count")

    # Sort the counts
    number_of_brewery_per_country = number_of_brewery_per_country.sort_values(ascending=False)

    # Count the number of reviews per user location
    nb_reviews_per_country = df['user_location'].value_counts()
    percentage_review = nb_reviews_per_country*100 / len(df)

    return df, number_of_brewery_per_country, percentage_review

# %%
all_data, brewery_per_country, percentage_review = count_and_filtering_us_uk(all_data)

# %%
### Plot numbers of breweries on a world map

#Initialisation of country converter to iso-3
cc = coco.CountryConverter()

#Convert country name to ISO3
df_tmp = brewery_per_country.copy()
df_tmp = df_tmp.to_frame()
df_tmp.reset_index(inplace=True)
countries = pd.Series(df_tmp['brewery_location'])
iso3_codes = cc.pandas_convert(countries, to='ISO3') #convert the name of the country to ISO3  
df_tmp.insert(1,"code",iso3_codes) #add a code column corresponding to ISO3 abreviation of the country
df_tmp = df_tmp.drop_duplicates(subset='code', keep='first')

#Plot 
colorblindscale = ["#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]
data = dict(type='choropleth', colorscale = colorblindscale,
           locations = df_tmp['code'], 
           z = df_tmp['count'], 
           text = df_tmp['brewery_location'])

layout = dict(title = 'Number of brewery per country',
              geo = dict( projection = {'type':'robinson'},
                         showlakes = False, 
                         lakecolor = 'rgb(0,191,255)'))
fig = pg.Figure(data = [data], layout = layout)

plot_format(fig, "brewery_world_map")
# Out:
# Transdniestra not found in regex
# Abkhazia not found in regex
# Tibet not found in regex
# Utah</a><br><a href="http://utahbeers.com" target="_blank">utahbeers.com not found in regex
# Nagorno-Karabakh not found in regex
# South Ossetia not found in regex

# %%
# Plot the percentage of reviews in histogram
percentage_review_top = percentage_review.head(10)
fig = px.bar(percentage_review_top, x=percentage_review_top.index, y=percentage_review_top, color=percentage_review_top.index, color_discrete_sequence=colorblindscale)
fig.update_layout(title_text='Percentage of reviews per country', xaxis_title="Country", yaxis_title="Percentage of reviews")
fig.update_xaxes(tickangle=45)
fig.update_layout(showlegend=False)
fig.update_layout(autosize=False, width=800, height=500)

plot_format(fig, "reviews_world_histogram")

# %% [markdown]
# Considering Canada, the US and the UK to be english speaking countries : over 82% of the reviews come from this countries. So one can assume that most of the reviews are in english. We need to check that assumption.

# %% [markdown]
# ### 2.3.2. Reviews' pre-processing

# %%
nltk.download('stopwords') # Download NLTK stopwords
nltk.download('wordnet')   # Lemmatization

english_words = set(wordnet.words())
english_stopwords = set(stopwords.words('english'))
specific_terms = {
    "umami", "hoppy", "malty", "saison", "abv", "ibu","hefeweizen", "ipa", "charred", "oaky", 
    "chocolaty", "progressing", "indulged", "pampered", "fulfilling", "create", "irked", "unpleased"
}

all_words = english_words.union(english_stopwords, specific_terms)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/tangzz/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/tangzz/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def keep_only_english(sentence):
    base_len = len(sentence)
    english_sentence = " ".join(w for w in nltk.wordpunct_tokenize(sentence) if w.lower() in all_words)
    if len(english_sentence) > 0.75*base_len:
        return english_sentence
    else:
        return None
    
def check_and_drop(df):
    df = df.dropna(subset=['text'])
    df = df[df['text'].str.strip().astype(bool)]  # Check for non-empty strings
    df = df[df['text'] != 'nan']
    before = df.shape[0]
    df['text'] = df['text'].apply(keep_only_english)
    df = df.dropna(subset=['text'])
    after = df.shape[0]
    diff = after / before * 100
    
    print(f"There is {round(diff, 2)}% of the reviews which are english")
    return df

# %%
# Pre-processing and checking accuracy
intial_shape = all_data.shape
all_data = check_and_drop(all_data)
cleaned_shape = all_data.shape
# Out:
# There is 85.98% of the reviews which are english

# %% [markdown]
# In the ratings, there are some people that have not made a textual review so we remove them to have equity in our ranking. We keep only english reviews because translating is too much calculative expensive, and require use of Google Translation API. The principal reason is also that around 86% of the reviews are in English and the polarity and subjectivity calculation need to be consistent.

# %% [markdown]
# # 3. Data Analysis

# %% [markdown]
# ## 3.1. Numerical ranking

# %% [markdown]
# In this section we will construct two rankings of the best breweries by grading them based on their beers' grade. We filter out the breweries with too few reviews to maintain the ranking credibility and ensure that the rating reflects a consensus among significant number of reviewers. This minimum number of review is set to 30 reviews, This threshold gives us a robust ranking. We tested with some lower threshold for instance 10 or 15, in those cases the best breweries contained 16 beers, only one of its beer had more than 5 reviews, which is not significant enough for us. Its average was very high due to the small number of reviews. As we will see later, a threshold of 30 gives a more robust ranking because the breweries have a satisfactory number of reviews. In both ranking we start by computing the averages obtained by each of the brewery's beers. Here is the first ranking system.

# %% [markdown]
# -  The first ranking is a weighted ranking, when computing the grade of the breweries we leverage the importance of each beer by the number of reviews it has received. This ranking isn't really sensitive to beers with a low number of reviews we thus don't filter out beers with little number of reviews.

# %% [markdown]
# However, this classification may not be considered representative of a brewery's quality. A brewery could have a very popular beer that is highly rated and drunk a lot, and the rest of its beers that are less highly rated and drunk less. This brewery in the first ranking will obtain a good average. However, the quality of the brewery can be questioned since only one of its beers is well rated.

# %% [markdown]
# - The second ranking takes this effect into account. It's a quality ranking as it doesn't take into account the quantity of review. It calculates a brewery's rating by averaging the beers without taking their frequency into account. This ranking could represent a better ranking of a brewery quality because it values quality among different beers. This ranking is very sensitive to beers that are rated very few times, which is why we have to filter out beers with too few reviews. We have decided that a beer with fewer than 4 reviews cannot be considered.

# %% [markdown]
# Additionally we will also explore the evolution of those ranking across the years.

# %% [markdown]
# ### 3.1.1. Filtering of the data

# %% [markdown]
# We first explore the distribution of the number of review per beers or breweries, to have an idea of the impact of our filtering on the data

# %%
def plot_reviews(beers, breweries):
    fig1 = go.Figure()
    fig1.add_trace(go.Histogram(x=beers, nbinsx=100, histfunc='sum', name='Number of Reviews per Beer', marker_color='blue', marker_opacity=0.7))
    fig1.update_layout(title='Distribution of the Number of Reviews per Beer',
                      xaxis_title='Number of Reviews',
                      yaxis_title='Count (log scale)',
                      yaxis_type='log')

    fig2 = go.Figure()
    fig2.add_trace(go.Histogram(x=breweries, nbinsx=100, histfunc='sum', name='Number of Reviews per Brewery', marker_color='red', marker_opacity=0.7))
    fig2.update_layout(title='Distribution of the Number of Reviews per Brewery',
                      xaxis_title='Number of Reviews',
                      yaxis_title='Count (log scale)',
                      yaxis_type='log')
    return fig1, fig2

# %%
nb_rev_beer = all_data.groupby('beer_name').apply(lambda x:len(x))
nb_rev_breweries = all_data.groupby('brewery_name').apply(lambda x:len(x))
fig1, fig2 = plot_reviews(nb_rev_beer, nb_rev_breweries)

display(plot_format(fig1, "reviews_beer_histogram"), plot_format(fig2, "reviews_breweries_histogram"))

# %% [markdown]
# Let's see how many beers are removed when we apply a threshold of 4 reviews per beer for the second rating system

# %%
ratings_filtered = all_data.groupby('beer_name').filter(lambda x: len(x)>4)
values =sum(1 for element in nb_rev_beer.values if element <= 4)
length_beer =len(nb_rev_beer.values)
length_review =all_data.shape[0]
print(f"We kicked {values} beers out of {length_beer} and {all_data.shape[0]-ratings_filtered.shape[0]} out of {all_data.shape[0]} reviews ")
print(f"which is {np.round(values/length_beer*100,3)}% of the beer and {np.round(100*(all_data.shape[0]-ratings_filtered.shape[0])/all_data.shape[0], 3)}% of the reviews")
# Out:
# We kicked 319976 beers out of 508771 and 584604 out of 8469180 reviews
# which is 62.892% of the beer and 6.903% of the reviews

# %% [markdown]
# Here we filter the breweries with less than 30 reviews and count the propotion of breweries removed
#
# ## Justify with a graph the threshold of 30 reviews per brewery

# %%
# apply the filter
all_data = all_data.groupby('brewery_name').filter(lambda x: len(x)>30)

kicked_brew = sum(1 for element in nb_rev_breweries.values if element <= 10)
length_brew = len(nb_rev_breweries.values)
print(f"We kicked {kicked_brew} breweries out of {length_brew}")# and {ratings_BA.shape[0]-length_review} out of {ratings_BA.shape[0]} reviews ")
print(f"which is {np.round(kicked_brew/length_brew*100,3)}% of the breweries")
# Out:
# We kicked 10973 breweries out of 28159
# which is 38.968% of the breweries

# %% [markdown]
# Functions for ranking per country and for comparing between different ranking systems

# %%
def create_ranking_per_country(ranking, col_name_rating):
    df_ranking = pd.DataFrame(ranking)
    
    df_ranking['brewery_location'] = df_ranking['brewery_location'].apply(lambda x: 'United States' if x.startswith('United States') else x)
    df_ranking['brewery_location'] = df_ranking['brewery_location'].apply(lambda x: 'United States' if x.startswith('United States') else x)
    ranking_per_country = df_ranking.drop_duplicates(subset='brewery_location')
    
    scaler = MinMaxScaler()
    ranking_per_country['final_grade'] = scaler.fit_transform(ranking_per_country[[col_name_rating]]).round(3)
    ranking_per_country['colormap'] = ranking_per_country['final_grade'].apply(lambda x: mcolors.to_hex(plt.cm.Reds(x)))
    return ranking_per_country

def plot_ranking(ranking_sorted, topN):
    plt.figure(figsize=(8, topN/4))
    colors = plt.cm.Reds(ranking_sorted[:topN] / ranking_sorted[:topN].max())
    plt.barh(ranking_sorted.index[:topN], ranking_sorted[:topN], color=colors)
    plt.gca().invert_yaxis()
    plt.title(f'Top {topN} Breweries of all time')
    plt.show()

def export_plot_ranking(ranking_sorted, topN, name):
    fig = go.Figure(data=[
        go.Bar(
            y=ranking_sorted.index[:topN][::-1],  # reverse order to have the same effect as invert_yaxis
            x=ranking_sorted[:topN][::-1],  # reverse order to have the same effect as invert_yaxis
            orientation='h',  # horizontal bar chart
            marker_color='rgba(222,45,38,0.8)'  # similar color to plt.cm.Reds
        )
    ])
    fig.update_layout(
        title_text=f'Top {topN} Breweries of all time',
        height=topN*60,  # adjust the height based on the number of bars
        width=800,
        xaxis_title="Ranking",
        yaxis_title="Breweries"
    )
    plot_format(fig, name)
    
def compare_ranking(ranking_sorted_1, ranking_sorted_2, topN):
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    
    colors_1 = plt.cm.Reds(ranking_sorted_1[:topN] / ranking_sorted_1[:topN].max())
    axes[0].barh(ranking_sorted_1.index[:topN], ranking_sorted_1[:topN], color=colors_1)
    axes[0].invert_yaxis()
    axes[0].set_title(f'Top {topN} Breweries - Weighted Ranking')
    
    colors_2 = plt.cm.Blues(ranking_sorted_2[:topN] / ranking_sorted_2[:topN].max())
    axes[1].barh(ranking_sorted_2.index[:topN], ranking_sorted_2[:topN], color=colors_2)
    axes[1].invert_yaxis()
    axes[1].set_title(f'Top {topN} Breweries - Quality Ranking')
    
    plt.tight_layout()
    plt.show()

def top_10_year(data, col, name):

    fig = {
        "data": [],
        "layout": {},
        "frames": []
    }
    # Supposons que vous ayez déjà défini la variable 'data' et 'top_entries' dans votre code précédent.

    # Initialize frames list and sliders dictionary
    frames = []
    sliders_dict = {"steps": []}
    beer_colors = {}

    for year in range(2000, int(data['year'].max()) + 1):
        # Filter data by year
        snap_data = data[data['year'] == year]

        # Sort by new_rating and get top 10
        snap_data = snap_data.sort_values(col, ascending=False).head(10)

        # Sort by new_rating in ascending order
        snap_data = snap_data.sort_values(col, ascending=True)

        # Generate colors for unique beer names
        for item in snap_data['brewery_name'].unique():
            if item not in beer_colors:
                beer_colors[item] = 'rgb({}, {}, {})'.format(*sample(range(256), 3))

        snap_data['color'] = snap_data['brewery_name'].map(beer_colors)
        max_rating_value = data[col].max()
        # Create frame
        frame = go.Frame(
            data=[
                go.Bar(
                    x=snap_data[col],
                    marker_color=snap_data['color'],
                    orientation='h',
                    hoverinfo='all',
                    text=snap_data['brewery_name'],
                    textposition='outside',
                    width=0.5
                )
            ],
            layout=go.Layout(
                font={'size': 14},
                plot_bgcolor='white',
                xaxis={
                    'showline': True,
                    'visible': True,
                    'range': (0, max_rating_value + 0.5)
                },
                bargap=0,
                bargroupgap=0,
                yaxis={
                    'showline': True,
                    'visible': True,
                    'tickvals': list(range(0, 11)),
                    'ticktext': list(range(10, 0, -1)),
                    'title_text': 'Top ' + str(10) + ' Breweries'
                },
                title=f'Top 10 Breweries in {year}',
            ),
            name=str(year),
        )

        # Append frame to list of frames
        frames.append(frame)

        # Define slider step
        slider_step = {
            "args": [
                [str(year)],
                {
                    "frame": {
                        "duration": 1000,
                        "redraw": True
                    },
                    "mode": "immediate",
                    "transition": {
                        "duration": 1000
                    }
                }
            ],
            "label": str(year),
            "method": "animate"
        }
        # Append to sliders_dict
        sliders_dict["steps"].append(slider_step)

    # Create figure
    fig = go.Figure(
        data=[go.Bar()],
        frames=frames,
    )

    # Update layout with play and pause buttons
    fig.update_layout(
        title='Top 10 Breweries in 2000',
        font={'size': 15},
        plot_bgcolor='white',
        xaxis={
            'showline': True,
            'visible': True,
            'title_text': col,
            'range': [0, max_rating_value+0.5]
        },
        yaxis={
            'showline': False,
            'visible': True,
            'tickvals': list(range(0, 11)),
            'ticktext': list(range(10, 0, -1)),
            'title_text': 'Top 10 Breweries'
        },
        height=400,
        width=800,
        margin=dict(
            l=100,
            t=50
        ),
        sliders=[sliders_dict],
    )
    plot_format(fig, name)
    
    return

# %% [markdown]
# The data is grouped by brewery and by beer. This number gives you the scores for each brewery. In the case of the classification by year, we also take into account the year.

# %%
grouped_brew = all_data.groupby(['brewery_name',"beer_name"])["std_rating"]
grouped_brew_year = all_data.groupby(['brewery_name',"beer_name","year"])["std_rating"]

# %% [markdown]
# ### 3.1.2. Weighted ranking

# %%
def weighted_ranking(data , version , col):
    if version == "all":
        grouped_brew = data.groupby(['brewery_name',"beer_name"])[col]
        grouped_agg = grouped_brew.agg(['mean', 'size'])
        grouped_agg['weighted_rating'] = grouped_agg['mean'] * grouped_agg['size']

        #Here we calculate the scores by taking into account the nb of ratings 
        nb_review = grouped_agg.groupby('brewery_name')['size'].sum()#.apply(lambda x : len(x))
        weighted_ranking = grouped_agg.groupby('brewery_name')['weighted_rating'].sum() / nb_review
        weighted_ranking_sorted = weighted_ranking.sort_values(ascending=False)
        return weighted_ranking_sorted
    else :
        grouped_brew_year = data.groupby(['brewery_name',"beer_name","year"])[col]
        grouped_agg_year = grouped_brew_year.agg(['mean', 'size'])
        grouped_agg_year['weighted_rating'] = grouped_agg_year['mean'] * grouped_agg_year['size']

        nb_review = grouped_agg_year.groupby('brewery_name')['size'].sum()
        weighted_ranking_year = grouped_agg_year.groupby(['brewery_name',"year"])['weighted_rating'].sum() / nb_review
        averaged_per_year = weighted_ranking_year.reset_index(level='brewery_name')
        averaged_per_year.columns.values[1] = col

        top_brewery_year_avg = averaged_per_year.groupby('year').apply(lambda x: x.nlargest(10, col))
    
        return top_brewery_year_avg.reset_index(0)

# %% [markdown]
# #### 3.1.2.1. All-time weighted ranking

# %%
weighted_ranking_sorted = weighted_ranking(all_data,"all","std_rating")
weighted_ranking_sorted_country = pd.merge(weighted_ranking_sorted.reset_index(), all_data[['brewery_name', 'brewery_location']], on='brewery_name', how='left')
weighted_ranking_sorted_country.columns = ['brewery_name', 'std_rating', 'brewery_location']

# %%
plot_ranking(weighted_ranking_sorted,10)

# %% [markdown]
# **Ranking per country**

# %%
weighted_ranking_per_country = create_ranking_per_country(weighted_ranking_sorted_country, 'std_rating')

# %% [markdown]
# #### 3.1.2.2. Weighted ranking per year

# %% [markdown]
# We compute the same ranking per year and only keep the top ten.

# %%
weighted_ranking_year_sorted = weighted_ranking(all_data,"year","std_rating")
top_10_year(weighted_ranking_year_sorted, "std_rating", "top10_weight")

# %% [markdown]
# ### 3.1.3. Quality-based ranking

# %% [markdown]
# As explained above, this ranking is more sensitive to beers with few reviews. We thus filter out beers with less than 4 reviews.

# %%
def quality_ranking(data , version , col):
    ratings_filtered = data.groupby('beer_name').filter(lambda x: len(x)>4)
    if version == "all":
    
        grouped_brew = ratings_filtered.groupby(['brewery_name',"beer_name"])[col]
        grouped_agg = grouped_brew.agg(['mean'])
        nb_beer = grouped_agg.groupby('brewery_name').apply(lambda x : len(x))
        quality_ranking = grouped_agg.groupby('brewery_name')['mean'].sum() / nb_beer
        #fair_ranking = grouped_agg.groupby('brewery_name')['mean'].mean()
        quality_ranking_sorted = quality_ranking.sort_values(ascending=False)

        return quality_ranking_sorted
    else :
        grouped_brew_year = ratings_filtered.groupby(['brewery_name',"beer_name","year"])[col]
        grouped_agg_year = grouped_brew_year.agg(['mean'])


        nb_beer = grouped_agg_year.groupby('brewery_name').apply(lambda x : len(x))
        quality_ranking_year = grouped_agg_year.groupby(['brewery_name',"year"])['mean'].sum() / nb_beer

        averaged_quality_per_year = quality_ranking_year.reset_index(level='brewery_name')
        averaged_quality_per_year.columns.values[1] = col

        top_brewery_year_quality = averaged_quality_per_year.groupby('year').apply(lambda x: x.nlargest(10, col))

        return top_brewery_year_quality.reset_index(0)

# %% [markdown]
# #### 3.1.3.1. All time quality ranking

# %%
quality_ranking_all = quality_ranking(all_data,"all","std_rating")

# %%
plot_ranking(quality_ranking_all,10)

# %% [markdown]
# #### 3.1.3.2. Quality ranking per year

# %% [markdown]
# As for the weighted system let's see the ranking per year

# %%
quality_ranking_year = quality_ranking(all_data,"year","std_rating")
top_10_year(quality_ranking_year, "std_rating",  "top10_quality")

# %% [markdown]
# Let's now compare the results of those two systems for the overall ranking.

# %% [markdown]
# ### 3.1.4. Comparison of the two all-time rankings

# %%
compare_ranking(weighted_ranking_sorted, quality_ranking_all, 10)

# %% [markdown]
# We observe that the top 10 breweries are approximately the same with a different order. These two rankings are thus consistent. However we decide to keep the weighted ranking for the datastory because it is less sensitive to beers with few reviews, and it is a better representation of people's opinion. The most important one.

# %%
export_plot_ranking(weighted_ranking_sorted, 10, "top10_alltime_weighted")

# %% [markdown]
# ## 3.2. Link between polarity, subjectivity of the reviews and ratings

# %% [markdown]
# ### 3.2.1. Calculations of polarity and subjectivity of the reviews with NLP analysis

# %% [markdown]
# For the sentimental analysis we use the TextBlob library for the subjectivity calculation. For the polarity calculation we use the Vader library. We use the Vader library because it is one of the most accurate library in sentiment analysis. We use the TextBlob library for the subjectivity calculation because it is more adapted to the beer reviews.

# %%
analyzer = SentimentIntensityAnalyzer()

def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return analyzer.polarity_scores(text)

# %%
# Calculate polarity rating (compound value) for each text 
all_data['polarity_rating'] = all_data['text'].apply(lambda x: getPolarity(x)['compound'])
# Calculate subjectivity for each text
all_data['subjectivity'] = all_data['text'].apply(lambda x: getSubjectivity(x))
all_data.head(5)
# Out:
#                  beer_name  beer_id                  brewery_name brewery_id  \
# 0            Posca Rustica    73367         Brasserie Dupont sprl        637
# 28                  Apathy    75684     Greenbush Brewing Company      25937
# 57                 Lucifer    54445           Brouwerij Het Anker       1534
# 80             Double Jack    50697  Firestone Walker Brewing Co.       2210
# 131  Green Flash Grand Cru    41345       Green Flash Brewing Co.       2743
#
#     brewery_location                                style        date  \
# 0            Belgium  Scottish Gruit / Ancient Herbed Ale  2012-08-23
# 28     United States                        Oatmeal Stout  2012-11-24
# 57           Belgium              Belgian Strong Pale Ale  2012-06-30
# 80     United States       American Double / Imperial IPA  2012-03-04
# 131    United States              Belgian Strong Dark Ale  2012-12-09
#
#         user_name              user_id  user_location  rating  \
# ...

# %% [markdown]
# ### 3.2.2. Statistics

# %% [markdown]
# We will use these datas to see if there is a correlation between the polarity and subjectivity of the reviews and the ratings. To verify that there is a lack in a ranking system based only on the ratings.
# We will check if there is a subjectivity's difference between extreme polarity reviews and rest of the reviews. Same process with the ratings to see if there is a difference of the subjectivity between the extreme ratings and the rest of the ratings.

# %%
def link_extreme_plotly(df, polarity_or_rating):
    """
    Compute the max and the min for the polarity and plot the subjectivity vs polarity for the extreme reviews.
    
    Parameters
    ----------
    df : DataFrame
        Contains data including 'polarity_rating' and 'subjectivity' columns.
    polarity_or_rating : str
        If polarity_or_rating = 'polarity_rating', use the polarity. If polarity_or_rating = 'std_rating', use the standardized rating.

    Returns
    -------
    fig : Figure
        Showing the link between subjectivity and polarity for the extreme reviews.
    p_value_pos : float
        p-value of the t-test for positive reviews.
    t_stat_pos : float
        t-statistic of the t-test for positive reviews.
    p_value_neg : float
        p-value of the t-test for negative reviews.
    t_stat_neg : float
        t-statistic of the t-test for negative reviews.
    """
    # Define max and min of the polarity
    q1 = df[polarity_or_rating].quantile(0.25)
    q3 = df[polarity_or_rating].quantile(0.75)
    iqr = q3 - q1

    max_value = q3 + 1.5 * iqr
    min_value = q1 - 1.5 * iqr

    # Filter the dataset to get only the max extreme values
    df_positive = df[df[polarity_or_rating] > max_value]
    df_negative = df[df[polarity_or_rating] < min_value]

    # Box plot for the subjectivity for positive reviews
    trace_positive = go.Box(x=df_positive['subjectivity'], name='Positive Reviews', line=dict(color='green'))

    # Box plot for all reviews
    trace_all = go.Box(x=df['subjectivity'], name='All Reviews', line=dict(color='blue'))
    
    # Box plot for the subjectivity for negative reviews
    trace_negative = go.Box(x=df_negative['subjectivity'], name='Negative Reviews', line=dict(color='red'))

    # Create a figure and add the traces
    fig = go.Figure(data=[trace_positive, trace_all, trace_negative])

    # Update layout and show figure
    fig.update_layout(title=('Subjectivity for extreme reviews based on' + ' ' + polarity_or_rating), xaxis_title='Subjectivity', width=800, height=400, legend=dict(yanchor="bottom", y=0.01, xanchor="left", x=0.01))

    # Adapt the dataset to perform Mann-Whitney U test (appropriate when the data may be skewed or not normally distributed.)
    # Positive reviews

    #The function mannwhitneyu does not accept empty distributions, this is why we need to check if the dataframe is empty or not
    if len(df_positive) == 0:
        p_pos = "NaN"
        stat_pos = "NaN"
    else:
        len_pos_df = len(df_positive)
        df_pos_bootstrap_sample = df.sample(n=len_pos_df, replace=True)

        # Perfoming Mann-Whitney U test
        stat_pos, p_pos = mannwhitneyu(df_positive['subjectivity'], df_pos_bootstrap_sample['subjectivity'])

    # Negative reviews
    if len(df_negative) == 0:
        p_neg = "NaN"
        stat_neg = "NaN"
    else:
        len_neg_df = len(df_negative)
        df_neg_bootstrap_sample = df.sample(n=len_neg_df, replace=True)

        # Perfoming Mann-Whitney U test
        stat_neg, p_neg = mannwhitneyu(df_negative['subjectivity'], df_neg_bootstrap_sample['subjectivity'])

    return fig, stat_pos, p_pos, stat_neg, p_neg

# %%
## Subjectivity for extreme polarites
# For positive reviews
fig, stat_pos_pol, p_pos_pol, stat_neg_pol, p_neg_pol = link_extreme_plotly(all_data, 'polarity_rating')

display(plot_format(fig, "Subjectivity_for_extreme_polarities"))

# Convert the figure to a static image file

# T-test for positivereviews
print(f'p_value for positive reviews: {p_pos_pol}')

# T-test for negative reviews
print(f'p_value for negative reviews: {p_neg_pol}')
# Out:
# p_value for positive reviews: NaN
# p_value for negative reviews: 0.0

# %% [markdown]
# The above plot shows the box plots for the subjectivity of all the reviews (in blue), against the distribution of subjectivity for reviews with extreme polarities (for positive reviews (in green) the distribution of subjectivity for reviews with a polarity above the computed maximum and for negative reviews (in red) below the computed min).
#
# #### Positive reviews
# The above plot shows that the boxplots for positive and all reviews do not overlap, it suggests that there is a substantial difference between the central tendencies of the two groups. So it seems that extremly positive reviews have a significantly higher subjectivity, this reviews need to be corrected to obtain a more ranking that is more fair.
#
# #### Negative reviews
# On the other hand the box plots for negative and all reviews partially overlap, it suggests that there are some similarities in the central 50% of the data. To conclude on the difference between the two distribution, the p-value needs to be looked at. In fact, the null hypothesis : " The two distribution have the same mean" is rejected since the p-value for negative reviews << 0.05. So on might say that the difference is significant and extremely negative reviews need to be corrected to get a more fair ranking.

# %%
## Subjectivity for extreme ratings
# For positive reviews
fig, stat_pos_rat, p_pos_rat, stat_neg_rat, p_neg_rat = link_extreme_plotly(all_data, 'std_rating')

display(plot_format(fig, "Subjectivity_for_extreme_ratings"))

# T-test for positivereviews
print(f'p_value for positive reviews: {p_pos_rat}')

# T-test for negative reviews
print(f'p_value for negative reviews: {p_neg_rat}')
# Out:
# p_value for positive reviews: 0.0
# p_value for negative reviews: 1.7561110711013336e-232

# %% [markdown]
# ## 3.3. NLP-Augmented ranking

# %% [markdown]
# #### 3.3.0 New ranking system

# %% [markdown]
# The initial rankings are solely based on numerical ratings. To enhance the fairness of our rating system, we have decided to incorporate textual reviews. To achieve this, we will consider the polarity of the comments, representing a score ranging from -1 (very negative) to 1 (very positive). However, it is crucial to acknowledge that individuals may introduce subjectivity into their ratings, denoted on a scale from 0 to 1, where 0 indicates objectivity and 1 signifies high subjectivity.
#
# In our quest for a fair ranking system, we aim to mitigate the impact of highly subjective opinions. To accomplish this, we introduce a coefficient (1-subjectivity), ensuring that individuals with more subjective views carry less weight in the final ranking.
#
# Additionally, we're streamlining our review process by standardizing all polarity scores together and not website by website as numerical ratings. This means that individuals expressing similar sentiments will receive the same polarity rating, irrespective of variations in their numerical ratings. For example, if two people share the same thoughts and emotions, one giving a rating of 3 and the other a 4, our machine learning system will assign them identical polarity ratings. This simplification ensures coherence and consistency in our overall ranking system.
#
# These explanations are summarized in the following formula:
#
# final_rating = (initial_rating + polarity) * (1-subjectivity)
#
# The last addition to this new rating algorithm is the introduction of a compensation factor `k`. It leads the final scores' correllation over the `std_rating` and `std_polarity_rating` dimensions to be the same. This factor is obtained through the minimization of an objective function that we have defined as the absolute value of difference between the _Pearson_ correlation factor along `std_rating` and `std_polarity_rating` dimensions. The minimization is performed using the `scipy.optimize.minimize` function.
#
# The final formula is thus:
#
# final_rating = (initial_rating + k * polarity) * (1-subjectivity)

# %%
# Apply the standardization to the polarity rating
all_data, _ = standardize_annually(all_data, 'polarity_rating')

# Evaluating the correlation between the initial rating and the polarity rating
print(f"Correlation factor for the initial rating against polarity: {pearsonr(all_data['std_rating'], all_data['std_polarity_rating'])[0]}")

# Function definition for optimization
def parametric_pearsonr_final_against_polarity(k: list):
    return pearsonr(all_data['std_polarity_rating'], (all_data['std_rating'] + k[0]*all_data['std_polarity_rating'])*(1-all_data['subjectivity']))[0]

def parametric_pearsonr_final_against_rating(k: list):
    return pearsonr(all_data['std_rating'], (all_data['std_rating'] + k[0]*all_data['std_polarity_rating'])*(1-all_data['subjectivity']))[0]

def objective_function(k: list):
    return abs(parametric_pearsonr_final_against_polarity(k) - parametric_pearsonr_final_against_rating(k))

# Optimization
input = [0.5] #Starting point
res = optimize.minimize(objective_function, input, method='Nelder-Mead', tol=1e-6)

print(f"Optimal k value: {round(res.x[0], 5)}")
print(f"Correlation factor for the final score against polarity: {round(parametric_pearsonr_final_against_polarity(res.x), 5)}")
print(f"Correlation factor for the final score against rating: {round(parametric_pearsonr_final_against_rating(res.x), 5)}")

# Augmented scoring feature addition following optimization results
all_data["new_rating"] = (all_data['std_rating'] + res.x[0]*all_data['std_polarity_rating'])*(1-all_data['subjectivity'])
# Out:
# Correlation factor for the initial rating against polarity: 0.3462095457427488
# Optimal k value: 0.93557
# Correlation factor for the final score against polarity: 0.79358
# Correlation factor for the final score against rating: 0.79358

# %% [markdown]
# A EXPLIQUER

# %% [markdown]
# ### 3.3.1. New weighted ranking

# %% [markdown]
# #### 3.3.1.1. All-time new weighted ranking

# %%
def plot_podium(ranking):
    ranking_3 = ranking.head(3)
    # Rearrange the DataFrame so that the highest-ranked brewery is in the middle
    ranking_3 = ranking_3.iloc[[1, 0, 2]]
    colors = ['silver', 'gold', 'brown']
    fig = go.Figure(data=[
        go.Bar(name='Breweries', x=ranking_3.index, y=ranking_3.values, marker_color=colors,
               text=["2nd", "1st", "3rd"], textposition='auto')  # Add numbers inside the bars
    ])

    # Label the axes and give the plot a title
    fig.update_layout(
        title='Ranking of Breweries',
        xaxis=dict(showgrid=False),  # Remove x-axis grid lines
        yaxis=dict(showticklabels=False, showgrid=False),  # Remove y-axis grid lines and labels
        showlegend=False,  # Hide the legend
        plot_bgcolor='rgba(0,0,0,0)',
        font=dict(size=20),  # Make plot background transparent
    )
    return fig

# %%
nlp_augmented_weighted_ranking_sorted = weighted_ranking(all_data,"all","new_rating")
nlp_augmented_weighted_ranking_sorted_country = pd.merge(nlp_augmented_weighted_ranking_sorted.reset_index(), all_data[['brewery_name', 'brewery_location']], on='brewery_name', how='left')
nlp_augmented_weighted_ranking_sorted_country.columns = ['brewery_name', 'new_rating', 'brewery_location']

# %%
plot_podium(nlp_augmented_weighted_ranking_sorted)
plot_format(fig, "ranking_breweries_Top3")

# %% [markdown]
# **Ranking per country**

# %%
new_weighted_ranking_per_country = create_ranking_per_country(nlp_augmented_weighted_ranking_sorted_country, 'new_rating')

# %%
new_weighted_ranking_per_country.head(5)
# Out:
#                                             brewery_name  new_rating  \
# 0                           Doggerlander Brewing Company    0.944312
# 42     Brouwerij Westvleteren (Sint-Sixtusabdij van W...    0.806301
# 9005                                        Neill & Ross    0.714750
# 18087                        Brasserie Auval Brewing Co.    0.668377
# 18377                         Tree House Brewing Company    0.668201
#
#       brewery_location  final_grade colormap
# 0              Ecuador        1.000  #67000d
# 42             Belgium        0.951  #7e0610
# 9005    United Kingdom        0.919  #8e0912
# 18087           Canada        0.903  #960b13
# 18377    United States        0.903  #960b13

# %%
weighted_ranking_per_country.head(5)
# Out:
#                         brewery_name  std_rating brewery_location  \
# 0       Doggerlander Brewing Company    1.801521          Ecuador
# 42     Westvleteren Abdij St. Sixtus    1.429731          Belgium
# 14957                 Ram Schaumburg    1.135412    United States
# 32778                   Neill & Ross    1.084128   United Kingdom
# 51450    Brasserie Auval Brewing Co.    0.988180           Canada
#
#        final_grade colormap
# 0            1.000  #67000d
# 42           0.919  #8e0912
# 14957        0.855  #ab1016
# 32778        0.844  #ad1117
# 51450        0.823  #b51318

# %% [markdown]
# #### 3.3.1.2. New weighted ranking per year

# %%
nlp_augmented_weighted_ranking_sorted_year = weighted_ranking(all_data,"year","new_rating")
top_10_year(nlp_augmented_weighted_ranking_sorted_year, "new_rating",  "top10_weight_new")

# %% [markdown]
# ### 3.3.2. New quality-based ranking

# %% [markdown]
# #### 3.3.2.1. All-time new quality-based ranking

# %%
nlp_augmented_quality_ranking_all = quality_ranking(all_data,"all","new_rating")

# %% [markdown]
# #### 3.3.2.2. New quality-based ranking per year

# %%
nlp_augmented_quality_ranking_sorted_year = quality_ranking(all_data,"year","new_rating")
top_10_year(nlp_augmented_quality_ranking_sorted_year, "new_rating", "top10_quality_new")

# %% [markdown]
# ### 3.3.3. Comparison of the two all-time augmented rankings

# %%
nlp_augmented_weighted_ranking_sorted
# Out:
# brewery_name
# Doggerlander Brewing Company                                  0.944312
# Brouwerij Westvleteren (Sint-Sixtusabdij van Westvleteren)    0.806301
# Westvleteren Abdij St. Sixtus                                 0.795286
# Neill & Ross                                                  0.714750
# Brasserie Rochefort                                           0.671294
#                                                                 ...
# Huanghe Beer Company (Carlsberg)                             -1.837313
# Kgalagadi Breweries (SABMiller)                              -1.898456
# Jebsen Beer                                                  -1.921197
# Sauvon Panimotupa                                            -1.945489
# Font Salem                                                   -1.988964
# Length: 12070, dtype: float64

# %%
compare_ranking(nlp_augmented_weighted_ranking_sorted, nlp_augmented_weighted_ranking_sorted, 10)

# %%
export_plot_ranking(nlp_augmented_weighted_ranking_sorted, 10, "top10_alltime_weighted_new")

# %% [markdown]
# # 4. Annexes

# %% [markdown]
# ## 4.1. GeoJson creation of the interactive world maps

# %%
def generate_geojson(df_weighted_raking_per_country, output_name):
    with open("docs/assets/json/geojson_template.json") as file:
        geo = json.loads(file.read())
    
    for brewery_location in df_weighted_raking_per_country.brewery_location.unique():
        for feature in geo['features']:
            if brewery_location in feature['properties']['NAME']:
                brewery_data = df_weighted_raking_per_country.loc[df_weighted_raking_per_country['brewery_location'] == brewery_location]
                feature['properties']['BEST_BREWERY'] = brewery_data['brewery_name'].values[0]
                feature['properties']['GRADE'] = brewery_data['final_grade'].values[0]
                feature['properties']['COLOR'] = brewery_data['colormap'].values[0]
    
    # Remove existing file if exists
    if os.path.exists("docs/assets/json/" + output_name + ".json"):
        os.remove("docs/assets/json/" + output_name + ".json")

    with open("docs/assets/json/" + output_name + ".json", "w") as file:
        json.dump(geo, file)

    # Displayaing the features of the first element
    print(json.dumps(geo['features'][0], indent=4))

# %%
weighted_ranking_per_country.head(10)
# Out:
#                          brewery_name  std_rating     brewery_location  \
# 0        Doggerlander Brewing Company    1.801521              Ecuador
# 42      Westvleteren Abdij St. Sixtus    1.429731              Belgium
# 14957                  Ram Schaumburg    1.135412        United States
# 32778                    Neill & Ross    1.084128       United Kingdom
# 51450     Brasserie Auval Brewing Co.    0.988180               Canada
# 167235   Western Herd Brewing Company    0.879368              Ireland
# 306639        Närke Kulturbryggeri AB    0.788168               Sweden
# 344152                Brewtal Brewers    0.755685            Australia
# 344249    Hürlimann (Feldschlösschen)    0.751418          Switzerland
# 344721                 Hart & Thistle    0.747595  Canada, Nova Scotia
#
#         final_grade colormap
# 0             1.000  #67000d
# 42            0.919  #8e0912
# 14957         0.855  #ab1016
# 32778         0.844  #ad1117
# 51450         0.823  #b51318
# ...

# %%
generate_geojson(weighted_ranking_per_country, "old_map")
generate_geojson(new_weighted_ranking_per_country, "new_map")
# Out:
# {
#     "type": "Feature",
#     "properties": {
#         "NAME": "Afghanistan",
#         "ISO_A2": "AF"
#     },
#     "bbox": [
#         60.52843,
#         29.318572,
#         75.158028,
#         38.486282
#     ],
#     "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#             [
#                 [
#                     61.210817,
#                     35.650072
#                 ],
#                 [
#                     62.230651,
#                     35.270664
#                 ],
#                 [
#                     62.984662,
#                     35.404041
#                 ],
#                 [
#                     63.193538,
#                     35.857166
#                 ],
#                 [
#                     63.982896,
#                     36.007957
#                 ],
#                 [
#                     64.546479,
#                     36.312073
#                 ],
#                 [
# ...

# %%
tac = datetime.now()

print(f"Time elapsed: {tac - tic}")
# Out:
# Time elapsed: 2:23:15.146600

# %%
all_data.to_csv("all_data_P3.csv")

# %% [markdown]
# ## 4.2. Generation of the table of content

# %%
# Load the .ipynb file
with open('./P3_final.ipynb', 'r') as f:
    notebook = nbformat.read(f, as_version=4)

# Extract the markdown cells
markdown_cells = [cell for cell in notebook['cells'] if cell['cell_type'] == 'markdown']

def levelf (lev, niv):
    i = lev[0:niv]
    string = ""
    for n in i:
        string = string + str(n) + "."
    string += " "
    return string

#Get all the markdown cells heading names and rename them with a sorted number and change the mardowns names in the notebook
index = [0, 0, 0, 0, 0, 0]
heading_corr = []
for i in range(len(notebook['cells'])):
    if notebook['cells'][i]['cell_type'] == 'markdown':
        if ('###### ') in notebook['cells'][i]['source'][0:7]:
            heading = notebook['cells'][i]['source']
            index[5] += 1
            level = levelf(index, 6)
            notebook['cells'][i]['source'] = '###### ' + level + heading[heading.rfind(". "):][2:] if ". " in heading else '###### ' + level + heading[7:]
            head = level + heading[heading.rfind(". "):][2:] if ". " in heading else level + heading[7:]
            heading_corr.append(["<a style='font-size:0.5em'>" + head + "</a>", head, level])
        elif ('##### ') in notebook['cells'][i]['source'][0:6]:
            heading = notebook['cells'][i]['source']
            index[4] += 1
            index[5] = 0
            level = levelf(index, 5)
            notebook['cells'][i]['source'] = '##### ' + level + heading[heading.rfind(". "):][2:] if ". " in heading else '##### ' + level + heading[6:]
            head = level + heading[heading.rfind(". "):][2:] if ". " in heading else level + heading[6:]
            heading_corr.append(["<a style='font-size:0.75em'>" + head + "</a>", head, level])
        elif ('#### ') in notebook['cells'][i]['source'][0:5]:
            heading = notebook['cells'][i]['source']
            index[3] += 1
            index[4] = 0
            index[5] = 0
            level = levelf(index, 4)
            notebook['cells'][i]['source'] = '#### ' + level + heading[heading.rfind(". "):][2:] if ". " in heading else '#### ' + level + heading[5:]
            head = level + heading[heading.rfind(". "):][2:] if ". " in heading else level + heading[5:]
            heading_corr.append(["<a style='font-size:1.25em'>" + head + "</a>", head, level])
        elif ('### ') in notebook['cells'][i]['source'][0:4]:
            heading = notebook['cells'][i]['source']
            index[2] += 1
            index[3] = 0
            index[4] = 0
            index[5] = 0
            level = levelf(index, 3)
            notebook['cells'][i]['source'] = '### ' + level + heading[heading.rfind(". "):][2:] if ". " in heading else '### ' + level + heading[4:]
            head = level + heading[heading.rfind(". "):][2:] if ". " in heading else level + heading[4:]
            heading_corr.append(["<a style='font-size:1.5em'>" + head + "</a>", head, level])
        elif ('## ') in notebook['cells'][i]['source'][0:3]:
            heading = notebook['cells'][i]['source']
            index[1] += 1
            index[2] = 0
            index[3] = 0
            index[4] = 0
            index[5] = 0
            level = levelf(index, 2)
            notebook['cells'][i]['source'] = '## ' + level + heading[heading.rfind(". "):][2:] if ". " in heading else '## ' + level + heading[3:]
            head = level + heading[heading.rfind(". "):][2:] if ". " in heading else level + heading[3:]
            heading_corr.append(["<a style='font-size:1.75em'>" + head + "</a>", head, level])
        elif ('# ') in notebook['cells'][i]['source'][0:2]:
            heading = notebook['cells'][i]['source']
            index[0] += 1
            index[1] = 0
            index[2] = 0
            index[3] = 0
            index[4] = 0
            index[5] = 0
            level = levelf(index, 1)
            notebook['cells'][i]['source'] = '# ' + level + heading[heading.rfind(". "):][2:] if ". " in heading else '# ' + level + heading[2:]
            head = level + heading[heading.rfind(". "):][2:] if ". " in heading else level + heading[2:]
            heading_corr.append(["<a style='font-size:2em'>" + head + "</a>", head, level])

# Combine lists
heading_corr
tab = "&emsp;"
# Generate the table of contents
toc = '\n'.join(f'{int(len(level)-3)*2*tab}[{ref}](#{ref.lower().replace(" ", "-")})  ' for heading, ref, level in heading_corr) #

# Write the updated notebook to disk
with open('./P3_final.ipynb', 'w+') as f:
    nbformat.write(notebook, f)

# %%
print(toc)
# Out:
# [1. Introduction](#1.-introduction)
# &emsp;&emsp;&emsp;&emsp;[1.1. Virtual environment setup](#1.1.-virtual-environment-setup)
# &emsp;&emsp;&emsp;&emsp;[1.2. Libraries import](#1.2.-libraries-import)
# &emsp;&emsp;&emsp;&emsp;[1.3. Paths definition](#1.3.-paths-definition)
# &emsp;&emsp;&emsp;&emsp;[1.4. Functions definition](#1.4.-functions-definition)
# [2. Data handling](#2.-data-handling)
# &emsp;&emsp;&emsp;&emsp;[2.1. Data import](#2.1.-data-import)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.1.1. Import text files](#2.1.1.-import-text-files)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.1.2. Load the other data](#2.1.2.-load-the-other-data)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.1.3. Data types](#2.1.3.-data-types)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;[2.1.3.1. Quick preprocessing to](#2.1.3.1.-quick-preprocessing-to)
# ...
